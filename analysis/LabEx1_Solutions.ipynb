# %% [markdown]
# ## <span style = "color:blue">Lab Exercise 1 Solutions (Total Marks: 12)</span>

# %% [markdown]
# 1. Google for a favourite quote of yours.Type the quote into a Markdown cell and demonstrate the use of the formatting  functions (heading, various font styles, indentation) and media display (insert a hyperlink and an image).(Hint: To attach and resize image, you could type **img src="attachment:imageName" width="pixelsNum"** within a pair of angle brackets.)

# %% [markdown]
# 2. Render the following expressions using LaTeX:
# <img src="attachment:LabEx1Qn2.png" width="350">
#
# (Hint: To show long right-pointing arrow, you could type **\longrightarrow**)

# %% [markdown]
# ### <span style = "color:blue">Question 1 (5 marks)</span>

# %% [markdown]
# ### <span style = "color:blue">Question 2 (7 marks)</span>
#
# $$ \sin^2\theta + \cos^2\theta = 1 $$
#
# $$ x_{n+1} = rx_n(1-x_n) $$
#
# $$ 6CO_2 + 6H_2O \longrightarrow C_6H_{12}O_{6} + 6O_{2} $$
#
# $$ P(x,\sigma,\mu) = \frac{1}{\sigma \sqrt{2\pi}}e^{-(x-\mu)^2/2\sigma^2} $$
#
# $$ y \approx \sqrt{1+\frac{1}{\sqrt[3]{1+\frac{1}{x}}}} $$
#
# $$ \sum\limits_{i=0}^{\infty}\frac{(k+i)!}{k!i!}x^i = \frac{1}{(1-x)^k} $$
#
# $$ \int_0^1\left[\int_0^3F(x,y,h)f(x)dx\right]^kf(y)dy = 3 $$
